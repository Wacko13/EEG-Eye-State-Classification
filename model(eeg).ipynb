# %%
import zipfile
import os

zip_path = "/content/archive.zip"

# Extract
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/data")

print("Extraction Done")
# Out:
# Extraction Done

# %%
os.listdir("/content/data")
# Out:
# ['EEG Eye State.arff', 'EEG_Eye_State_Classification.csv']

# %%
import pandas as pd

file_path = "/content/data/EEG_Eye_State_Classification.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#        AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         P8       T8      FC6       F4       F8      AF4  eyeDetection
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85             0
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10             0
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23             0
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41             0
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46             0

# %%
df.shape
# Out:
# (14980, 15)

# %%
df.columns
# Out:
# Index(['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6',
#        'F4', 'F8', 'AF4', 'eyeDetection'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14980 entries, 0 to 14979
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AF3           14980 non-null  float64
#  1   F7            14980 non-null  float64
#  2   F3            14980 non-null  float64
#  3   FC5           14980 non-null  float64
#  4   T7            14980 non-null  float64
#  5   P7            14980 non-null  float64
#  6   O1            14980 non-null  float64
#  7   O2            14980 non-null  float64
#  8   P8            14980 non-null  float64
#  9   T8            14980 non-null  float64
#  10  FC6           14980 non-null  float64
#  11  F4            14980 non-null  float64
#  12  F8            14980 non-null  float64
#  13  AF4           14980 non-null  float64
#  14  eyeDetection  14980 non-null  int64
# dtypes: float64(14), int64(1)
# memory usage: 1.7 MB

# %%
df.isnull().sum()
# Out:
# AF3             0
# F7              0
# F3              0
# FC5             0
# T7              0
# P7              0
# O1              0
# O2              0
# P8              0
# T8              0
# FC6             0
# F4              0
# F8              0
# AF4             0
# eyeDetection    0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
# Split Features and Labels
X = df.drop("eyeDetection", axis=1)
y = df["eyeDetection"]

print("X shape:", X.shape)
print("y shape:", y.shape)


# Normalize
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Data normalized")


# Train-Test Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# X shape: (14980, 14)
# y shape: (14980,)
# Data normalized
# Training data: (11984, 14)
# Testing data: (2996, 14)

# %%
y.value_counts()
# Out:
# eyeDetection
# 0    8257
# 1    6723
# Name: count, dtype: int64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# Input + Hidden Layer 1
model.add(Dense(8, activation='relu', input_shape=(14,)))

# Hidden Layer 2
model.add(Dense(8, activation='relu'))

# Output Layer (Binary Classification)
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5558 - loss: 0.6817 - val_accuracy: 0.5678 - val_loss: 0.6697
# Epoch 2/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5824 - loss: 0.6608 - val_accuracy: 0.5824 - val_loss: 0.6548
# Epoch 3/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5942 - loss: 0.6513 - val_accuracy: 0.6016 - val_loss: 0.6468
# Epoch 4/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6064 - loss: 0.6455 - val_accuracy: 0.6099 - val_loss: 0.6416
# Epoch 5/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6135 - loss: 0.6403 - val_accuracy: 0.6162 - val_loss: 0.6379
# Epoch 6/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6225 - loss: 0.6347 - val_accuracy: 0.6162 - val_loss: 0.6324
# Epoch 7/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6318 - loss: 0.6288 - val_accuracy: 0.6300 - val_loss: 0.6272
# Epoch 8/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6379 - loss: 0.6230 - val_accuracy: 0.6275 - val_loss: 0.6219
# Epoch 9/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6441 - loss: 0.6178 - val_accuracy: 0.6370 - val_loss: 0.6178
# Epoch 10/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6504 - loss: 0.6126 - val_accuracy: 0.6366 - val_loss: 0.6137
# Epoch 11/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6539 - loss: 0.6078 - val_accuracy: 0.6441 - val_loss: 0.6089
# Epoch 12/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6570 - loss: 0.6036 - val_accuracy: 0.6466 - val_loss: 0.6052
# Epoch 13/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6625 - loss: 0.5991 - val_accuracy: 0.6496 - val_loss: 0.5994
# Epoch 14/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6648 - loss: 0.5945 - val_accuracy: 0.6558 - val_loss: 0.5983
# Epoch 15/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6669 - loss: 0.5931 - val_accuracy: 0.6637 - val_loss: 0.5940
# Epoch 16/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6718 - loss: 0.5888 - val_accuracy: 0.6700 - val_loss: 0.5897
# Epoch 17/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6721 - loss: 0.5859 - val_accuracy: 0.6704 - val_loss: 0.5880
# Epoch 18/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6794 - loss: 0.5825 - val_accuracy: 0.6692 - val_loss: 0.5867
# Epoch 19/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6796 - loss: 0.5799 - val_accuracy: 0.6746 - val_loss: 0.5843
# Epoch 20/20
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6801 - loss: 0.5776 - val_accuracy: 0.6783 - val_loss: 0.5803

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy:", accuracy)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6669 - loss: 0.5870
# Test Accuracy: 0.6668891906738281

# %%
import matplotlib.pyplot as plt
#Accuracy & Loss Graphs

# Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
#Confusion Matrix

from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Predictions
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# Classification Report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion Matrix:
#  [[1242  344]
#  [ 654  756]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71      1586
#            1       0.69      0.54      0.60      1410
#
#     accuracy                           0.67      2996
#    macro avg       0.67      0.66      0.66      2996
# weighted avg       0.67      0.67      0.66      2996

# %%
#for upgrading
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(14,)))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
svm = SVC()

svm.fit(X_train, y_train)

pred = svm.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, pred))
# Out:
# SVM Accuracy: 0.613150867823765

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Models
models = {
    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        random_state=42
    ),
    "SVM": SVC(),
}

accuracies = {}

# Train & Evaluate
for name, model in models.items():

    model.fit(X_train, y_train)

    predictions = model.predict(X_test)

    acc = accuracy_score(y_test, predictions)

    accuracies[name] = acc * 100

    print(f"{name}: {acc*100:.2f}%")

# Plot
plt.figure(figsize=(8,5))

bars = plt.bar(
    accuracies.keys(),
    accuracies.values()
)

plt.title("Model Accuracy Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy (%)")
plt.ylim(0,100)

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 1,
        f"{height:.2f}%",
        ha='center'
    )

plt.show()
# Out:
# Random Forest: 92.46%
# SVM: 61.32%

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(
    rf,
    X_test,
    y_test
)

plt.title("Random Forest Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

rf_probs = rf.predict_proba(X_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, rf_probs)

roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Random Forest ROC Curve")
plt.legend()
plt.show()

# %%
#DEMO

# %%
import pandas as pd

idx = random.randint(0, len(X_test)-1)

sample = X_test[idx].reshape(1,-1)

actual = y_test.iloc[idx]

predicted = rf.predict(sample)[0]

probability = rf.predict_proba(sample)[0]

result = pd.DataFrame({
    "Actual Class":[actual],
    "Predicted Class":[predicted],
    "Open Probability (%)":[round(probability[0]*100,2)],
    "Closed Probability (%)":[round(probability[1]*100,2)]
})

print(result)
# Out:
#    Actual Class  Predicted Class  Open Probability (%)  Closed Probability (%)
# 0             0                0                  53.5                    46.5
